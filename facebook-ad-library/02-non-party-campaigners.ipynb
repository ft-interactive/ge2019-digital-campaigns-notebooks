# %%
import pandas as pd
import re

# %% [markdown]
# ## Utility functions

# %%
def is_registered_disclaimer(disclaimer, campaigner_names):
    regex = re.compile("limited|ltd|ltd\.|uk$")
    disclaimer_lower = regex.sub("", disclaimer.lower().strip())
    registered_campaigner = ""

    for campaigner_name in campaigner_names:
        if disclaimer_lower in regex.sub("", campaigner_name.lower().strip()):
            registered_campaigner = campaigner_name

    return registered_campaigner

# %% [markdown]
# ## Load registered non-party campaigners from Electoral Commission

# %%
df_campaigners = pd.read_csv(
    "../data/raw/non-party-campaigners-2019-12-04.csv",
    usecols=[*range(0, 4), 5, *range(8, 15)],
    dtype={"CompanyRegistrationNumber": "str"},
    parse_dates=["ApprovedDate"],
)

print(len(df_campaigners))
print(df_campaigners.dtypes)
df_campaigners.head()
# Out:
# 64
# ECRef                                   object
# RegulatedEntityName                     object
# RegulatedEntityTypeName                 object
# RegistrationStatusName                  object
# EntityStatusName                        object
# CompanyRegistrationNumber               object
# ApprovedDate                    datetime64[ns]
# FieldingCandidatesInEngland               bool
# FieldingCandidatesInScotland              bool
# FieldingCandidatesInWales                 bool
# FieldingCandidatesInEurope                bool
# FieldingCandidatesMinorParty              bool
# dtype: object
#      ECRef                                RegulatedEntityName  \
# 0  TP10305                                     Jeremy Hosking
# 1  TP10345   Richard Patrick Tracey - campaign name Parent...
# 2  TP10246                                         38 Degrees
# 3  TP10354                                      3rd Party Ltd
# 4  TP11355                                   Advance Together
#
#   RegulatedEntityTypeName RegistrationStatusName            EntityStatusName  \
# 0             Third Party             Registered                  Individual
# 1             Third Party             Registered                  Individual
# 2             Third Party             Registered                     Company
# 3             Third Party             Registered                     Company
# 4             Third Party             Registered  Registered Political Party
#
#   CompanyRegistrationNumber ApprovedDate  FieldingCandidatesInEngland  \
# 0                       NaN   2019-10-14                        False
# 1                       NaN   2019-11-11                        False
# 2                  06642193   2019-09-30                        False
# 3                  12313483   2019-11-28                        False
# 4                       NaN   2019-11-14                        False
#
#    FieldingCandidatesInScotland  FieldingCandidatesInWales  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    FieldingCandidatesInEurope  FieldingCandidatesMinorParty
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False

# %% [markdown]
# ## Load advertisers over last 30 days from Ad Library report

# %%
df_fb_30d = (
    pd.read_csv(
        "../data/raw/facebook-ad-library/FacebookAdLibraryReport_2019-12-01_GB_last_30_days/"
        "FacebookAdLibraryReport_2019-12-01_GB_last_30_days_advertisers.csv"
    )
    .rename(
        {
            "Page ID": "page_id",
            "Page Name": "page_name",
            "Disclaimer": "disclaimer",
            "Amount Spent (GBP)": "amount_spent_gbp",
            "Number of Ads in Library": "number_of_ads_in_library",
        },
        axis=1,
    )
    .query("amount_spent_gbp != '≤100'")
    .astype({"amount_spent_gbp": "int64", "number_of_ads_in_library": "int64"})
    .sort_values("amount_spent_gbp", ascending=False)
    .reset_index(drop=True)
)

print(len(df_fb_30d))
print(df_fb_30d.dtypes)
df_fb_30d.head()
# Out:
# 997
# page_id                      int64
# page_name                   object
# disclaimer                  object
# amount_spent_gbp             int64
# number_of_ads_in_library     int64
# dtype: object
#             page_id          page_name  \
# 0        5883973269  Liberal Democrats
# 1       25749647410   The Labour Party
# 2   230416667843105   The Brexit Party
# 3  1863944713844924   Best For Britain
# 4      330250343871      Jeremy Corbyn
#
#                                     disclaimer  amount_spent_gbp  \
# 0                        the Liberal Democrats            539483
# 1                             The Labour Party            414022
# 2                             The Brexit Party            226833
# 3                             Best For Britain            202795
# 4  The Labour Party on behalf of Jeremy Corbyn            175323
#
#    number_of_ads_in_library
# 0                      6625
# 1                       654
# 2                      1493
# 3                       137
# 4                        37

# %%
df_registered = (
    df_fb_30d.copy()
    .assign(
        registered_disclaimer=lambda df: df["disclaimer"].apply(
            lambda x: is_registered_disclaimer(x, df_campaigners["RegulatedEntityName"])
        )
    )
    .query("registered_disclaimer != ''")
    .groupby("registered_disclaimer", as_index=False)[
        ["amount_spent_gbp", "number_of_ads_in_library"]
    ]
    .sum()
    .sort_values("amount_spent_gbp", ascending=False)
    .reset_index(drop=True)
)

print(len(df_registered))
print(df_registered.dtypes)
print(f"Total spending: £", df_registered["amount_spent_gbp"].sum())
df_registered
# Out:
# 26
# registered_disclaimer       object
# amount_spent_gbp             int64
# number_of_ads_in_library     int64
# dtype: object
# Total spending: £ 585633
#                                 registered_disclaimer  amount_spent_gbp  \
# 0   UK-EU Open Policy Limited (campaign name: Best...            202795
# 1                                  Greenpeace Limited             64057
# 2                            National Education Union             56634
# 3                                   HOPE not hate Ltd             52963
# 4                    Momentum Campaign (Services) Ltd             39366
# 5                                          38 Degrees             32500
# 6                        Friends of the Earth Limited             28211
# 7                                Working 4 UK Limited             23326
# 8    Richard Patrick Tracey - campaign name Parent...             15179
# 9                                   Capitalist Worker             12503
# 10      Referendum Facts Ltd (campaign name: InFacts)             12208
# 11                              Fair Tax Campaign Ltd              8849
# 12                           Centrum Campaign Limited              8500
# 13                              Labour Future Limited              8331
# 14                                Led By Donkeys Ltd.              5826
# 15                              Scientists for EU Ltd              3281
# 16  MTCAE Limited (campaign name: Mainstream - The...              2473
# 17                     Another Europe is Possible Ltd              1580
# 18                                    Unite the Union              1570
# 19       European Movement of the United Kingdom Ltd.              1094
# 20                              Kent Citizens Limited              1094
# 21  PV Media Hub Limited (campaign name: Vote for ...               843
# 22                                 Avaaz Campaigns UK               842
# 23                    The League Against Cruel Sports               786
# 24                                 Global Justice Now               480
# 25                                    More United Ltd               342
#
#     number_of_ads_in_library
# 0                        137
# 1                         72
# 2                        494
# 3                       2627
# 4                         54
# 5                        104
# 6                       2369
# 7                         27
# 8                         20
# 9                         23
# 10                        25
# 11                        19
# 12                        29
# 13                        63
# 14                        27
# 15                        11
# 16                        18
# 17                        13
# 18                         2
# 19                        44
# 20                        12
# 21                       188
# 22                         8
# 23                         7
# 24                        29
# 25                         4
